# %% [markdown]
# *Topics Covered
# ->Ai vs Machine Learning vs Deep Learning vs Generative AI
# ->AI use cases
# ->Software Development Life Cycle (SDLC)
# ->Installed Python and configured environment variables
# ->Installed Visual Studio Code
# ->Installed the Python and Jupyter extensions in VS Code
# ->Installed Git
# ->Created a GitHub account
# ->Initialized a Git repository
# ->Cloned and pushed a repository to GitHub
# ->Created and activated a virtual environment (venv)
# Explored AI coding assistants:
# ChatGPT
